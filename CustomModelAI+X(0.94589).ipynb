# %%
#Drive Mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#GPU 
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#Data load
import numpy as np
import pandas as pd

X_train = np.load('/content/drive/MyDrive/딥러닝 AI+X/train_x.npy')
Y_train = np.load('/content/drive/MyDrive/딥러닝 AI+X/train_y.npy')
X_test = np.load('/content/drive/MyDrive/딥러닝 AI+X/test_x.npy')
Y_test  = pd.read_csv("/content/drive/MyDrive/딥러닝 AI+X/submission.csv").values
print(np.shape(X_train))
print(np.shape(Y_train))
print(np.shape(X_test))
print(np.shape(Y_test))
# Out:
# (7494, 128, 6)
# (7494, 9)
# (3217, 128, 6)
# (3217, 2)

# %%
#Model Library
from keras.models import Sequential, Model
from keras.layers import Conv1D, MaxPooling1D,BatchNormalization
from keras.callbacks import EarlyStopping, LambdaCallback
from keras.layers import Activation, Dropout,Input, Flatten, Dense

# %%
#Convolutional Layer
model = Sequential()
model.add(Conv1D(32, kernel_size=3, input_shape=(128, 6),padding = 'same'))
model.add(BatchNormalization(axis=-1))
model.add(Dense(32, activation='relu'))


model.add(Conv1D(64, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(64, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

model.add(Conv1D(128, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(128, activation='relu'))


model.add(Conv1D(256, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(256, activation='relu'))


model.add(Conv1D(512, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(512, activation='relu'))


model.add(Conv1D(1024, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(1024, activation='relu'))

model.add(Conv1D(2048, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(2048, activation='relu'))

# %%
#Output Layer
model.add(Flatten())
model.add(Dense(2048, activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(9, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_12 (Conv1D)           (None, 128, 32)           608
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 128, 32)           128
# _________________________________________________________________
# dense_15 (Dense)             (None, 128, 32)           1056
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 126, 64)           6208
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 126, 64)           256
# _________________________________________________________________
# dense_16 (Dense)             (None, 126, 64)           4160
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 63, 64)            0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 61, 128)           24704
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 61, 128)           512
# _________________________________________________________________
# dense_17 (Dense)             (None, 61, 128)           16512
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 59, 256)           98560
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 59, 256)           1024
# _________________________________________________________________
# dense_18 (Dense)             (None, 59, 256)           65792
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 57, 512)           393728
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 57, 512)           2048
# _________________________________________________________________
# dense_19 (Dense)             (None, 57, 512)           262656
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 55, 1024)          1573888
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 55, 1024)          4096
# _________________________________________________________________
# dense_20 (Dense)             (None, 55, 1024)          1049600
# _________________________________________________________________
# conv1d_18 (Conv1D)           (None, 53, 2048)          6293504
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 53, 2048)          8192
# _________________________________________________________________
# dense_21 (Dense)             (None, 53, 2048)          4196352
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 108544)            0
# _________________________________________________________________
# dense_22 (Dense)             (None, 2048)              222300160
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 2048)              8192
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 2048)              8192
# _________________________________________________________________
# dense_23 (Dense)             (None, 9)                 18441
# =================================================================
# Total params: 236,338,569
# Trainable params: 236,322,249
# Non-trainable params: 16,320
# _________________________________________________________________

# %%
#만약 overfitting, underfitting 을 일으키면 EarlyStopping을 쓰기 위한 코드
#patience가 5면 validation score가 5회 이상 개선이 없을때 훈련을 멈춘다

from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_accuracy', patience=5, min_delta=0.005)

# %%
#model traing
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy']) #rmsprop or adam , accuracy or f1-score  (positive와 negative의 데이터 값 차이가 높을 경우)
history = model.fit(X_train,Y_train, epochs=100, batch_size=20) #callbacks=[es])
# Out:
# Epoch 1/100
# 375/375 [==============================] - 72s 64ms/step - loss: 1.1360 - accuracy: 0.6817
# Epoch 2/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.3574 - accuracy: 0.8682
# Epoch 3/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.2287 - accuracy: 0.9087
# Epoch 4/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.1964 - accuracy: 0.9159
# Epoch 5/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1717 - accuracy: 0.9303
# Epoch 6/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1690 - accuracy: 0.9286
# Epoch 7/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1446 - accuracy: 0.9398
# Epoch 8/100
# 375/375 [==============================] - 25s 65ms/step - loss: 0.1454 - accuracy: 0.9404
# Epoch 9/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1243 - accuracy: 0.9520
# Epoch 10/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1226 - accuracy: 0.9483
# Epoch 11/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1207 - accuracy: 0.9493
# Epoch 12/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1208 - accuracy: 0.9492
# Epoch 13/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1319 - accuracy: 0.9469
# Epoch 14/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1015 - accuracy: 0.9597
# Epoch 15/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1042 - accuracy: 0.9601
# Epoch 16/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0861 - accuracy: 0.9654
# Epoch 17/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1008 - accuracy: 0.9582
# Epoch 18/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1066 - accuracy: 0.9584
# Epoch 19/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0946 - accuracy: 0.9637
# Epoch 20/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1050 - accuracy: 0.9558
# Epoch 21/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0909 - accuracy: 0.9592
# Epoch 22/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0884 - accuracy: 0.9649
# Epoch 23/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0747 - accuracy: 0.9705
# Epoch 24/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0824 - accuracy: 0.9675
# Epoch 25/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0861 - accuracy: 0.9621
# Epoch 26/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0870 - accuracy: 0.9616
# Epoch 27/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0759 - accuracy: 0.9692
# Epoch 28/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0797 - accuracy: 0.9693
# Epoch 29/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0737 - accuracy: 0.9714
# Epoch 30/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0862 - accuracy: 0.9678
# Epoch 31/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0618 - accuracy: 0.9745
# Epoch 32/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0791 - accuracy: 0.9702
# Epoch 33/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0785 - accuracy: 0.9665
# Epoch 34/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0795 - accuracy: 0.9699
# Epoch 35/100
# 375/375 [==============================] - 25s 65ms/step - loss: 0.0671 - accuracy: 0.9734
# Epoch 36/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0677 - accuracy: 0.9737
# Epoch 37/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0703 - accuracy: 0.9708
# Epoch 38/100
# 375/375 [==============================] - 25s 65ms/step - loss: 0.0661 - accuracy: 0.9766
# Epoch 39/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0642 - accuracy: 0.9746
# Epoch 40/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0541 - accuracy: 0.9805
# Epoch 41/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0689 - accuracy: 0.9746
# Epoch 42/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0554 - accuracy: 0.9761
# Epoch 43/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0581 - accuracy: 0.9759
# Epoch 44/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0553 - accuracy: 0.9806
# Epoch 45/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0535 - accuracy: 0.9781
# Epoch 46/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0584 - accuracy: 0.9786
# Epoch 47/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0595 - accuracy: 0.9762
# Epoch 48/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0525 - accuracy: 0.9799
# Epoch 49/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0564 - accuracy: 0.9774
# Epoch 50/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0424 - accuracy: 0.9810
# Epoch 51/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0468 - accuracy: 0.9840
# Epoch 52/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0617 - accuracy: 0.9779
# Epoch 53/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0408 - accuracy: 0.9849
# Epoch 54/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0544 - accuracy: 0.9783
# Epoch 55/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0530 - accuracy: 0.9790
# Epoch 56/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0433 - accuracy: 0.9827
# Epoch 57/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0592 - accuracy: 0.9751
# Epoch 58/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0499 - accuracy: 0.9792
# Epoch 59/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0406 - accuracy: 0.9860
# Epoch 60/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0687 - accuracy: 0.9733
# Epoch 61/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0650 - accuracy: 0.9726
# Epoch 62/100
# 375/375 [==============================] - 25s 65ms/step - loss: 0.0463 - accuracy: 0.9822
# Epoch 63/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0461 - accuracy: 0.9815
# Epoch 64/100
# 375/375 [==============================] - 25s 67ms/step - loss: 0.0364 - accuracy: 0.9868
# Epoch 65/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0405 - accuracy: 0.9836
# Epoch 66/100
# 375/375 [==============================] - 25s 65ms/step - loss: 0.0375 - accuracy: 0.9876
# Epoch 67/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0422 - accuracy: 0.9833
# Epoch 68/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0260 - accuracy: 0.9892
# Epoch 69/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0434 - accuracy: 0.9844
# Epoch 70/100
# 375/375 [==============================] - 25s 65ms/step - loss: 0.0338 - accuracy: 0.9880
# Epoch 71/100
# 375/375 [==============================] - 25s 65ms/step - loss: 0.0336 - accuracy: 0.9866
# Epoch 72/100
# 375/375 [==============================] - 25s 65ms/step - loss: 0.0309 - accuracy: 0.9880
# Epoch 73/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0284 - accuracy: 0.9898
# Epoch 74/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0329 - accuracy: 0.9867
# Epoch 75/100
# 375/375 [==============================] - 25s 65ms/step - loss: 0.0290 - accuracy: 0.9907
# Epoch 76/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0201 - accuracy: 0.9928
# Epoch 77/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0250 - accuracy: 0.9904
# Epoch 78/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0279 - accuracy: 0.9891
# Epoch 79/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0156 - accuracy: 0.9953
# Epoch 80/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0356 - accuracy: 0.9887
# Epoch 81/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0250 - accuracy: 0.9906
# Epoch 82/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0290 - accuracy: 0.9894
# Epoch 83/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0210 - accuracy: 0.9918
# Epoch 84/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0337 - accuracy: 0.9886
# Epoch 85/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0263 - accuracy: 0.9901
# Epoch 86/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0254 - accuracy: 0.9907
# Epoch 87/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0312 - accuracy: 0.9891
# Epoch 88/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0173 - accuracy: 0.9938
# Epoch 89/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0143 - accuracy: 0.9944
# Epoch 90/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0156 - accuracy: 0.9947
# Epoch 91/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0224 - accuracy: 0.9918
# Epoch 92/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0216 - accuracy: 0.9931
# Epoch 93/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0158 - accuracy: 0.9957
# Epoch 94/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0290 - accuracy: 0.9886
# Epoch 95/100
# 375/375 [==============================] - 25s 65ms/step - loss: 0.0233 - accuracy: 0.9915
# Epoch 96/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0141 - accuracy: 0.9956
# Epoch 97/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0235 - accuracy: 0.9919
# Epoch 98/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0138 - accuracy: 0.9953
# Epoch 99/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0187 - accuracy: 0.9929
# Epoch 100/100
# 375/375 [==============================] - 25s 66ms/step - loss: 0.0140 - accuracy: 0.9947

# %%
#훈련 및 검증 정확도 시각화
#학습 정확성 값과 검증 정확성 값
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# 학습 손실 값과 검증 손실 값
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# %%
preds = model.predict(X_test)
preds = np.argmax(preds, axis=1)
preds
# Out:
# array([4, 1, 4, ..., 2, 0, 2])

# %%
#model save
submission = pd.read_csv('/content/drive/MyDrive/딥러닝 AI+X/submission.csv')
submission['Predicted Label'] = preds
submission.to_csv('submission_file.csv', index=False)
submission
# Out:
#       Trial  Predicted Label
# 0         0                4
# 1         1                1
# 2         2                4
# 3         3                0
# 4         4                0
# ...     ...              ...
# 3212   3212                5
# 3213   3213                1
# 3214   3214                2
# 3215   3215                0
# 3216   3216                2
#
# [3217 rows x 2 columns]
