# %%
#Drive Mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#GPU 
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#Data load
import numpy as np
import pandas as pd

X_train = np.load('/content/drive/MyDrive/딥러닝 AI+X/train_x.npy')
Y_train = np.load('/content/drive/MyDrive/딥러닝 AI+X/train_y.npy')
X_test = np.load('/content/drive/MyDrive/딥러닝 AI+X/test_x.npy')
Y_test  = pd.read_csv("/content/drive/MyDrive/딥러닝 AI+X/submission.csv").values
print(np.shape(X_train))
print(np.shape(Y_train))
print(np.shape(X_test))
print(np.shape(Y_test))
# Out:
# (7494, 128, 6)
# (7494, 9)
# (3217, 128, 6)
# (3217, 2)

# %%
#Model Library
from keras.models import Sequential, Model
from keras.layers import Conv1D, MaxPooling1D,BatchNormalization
from keras.callbacks import EarlyStopping, LambdaCallback
from keras.layers import Activation, Dropout,Input, Flatten, Dense

# %%
#Convolutional Layer
model = Sequential()
model.add(Conv1D(32, kernel_size=3, input_shape=(128, 6),padding = 'same'))
model.add(BatchNormalization(axis=-1))
model.add(Dense(32, activation='relu'))


model.add(Conv1D(64, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(64, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

model.add(Conv1D(128, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(128, activation='relu'))


model.add(Conv1D(256, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(256, activation='relu'))


model.add(Conv1D(512, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(512, activation='relu'))


model.add(Conv1D(1024, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(1024, activation='relu'))

model.add(Conv1D(2048, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(2048, activation='relu'))

# %%
#Output Layer
model.add(Flatten())
model.add(Dense(2048, activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(9, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 128, 32)           608
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 32)           128
# _________________________________________________________________
# dense (Dense)                (None, 128, 32)           1056
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 126, 64)           6208
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 126, 64)           256
# _________________________________________________________________
# dense_1 (Dense)              (None, 126, 64)           4160
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 63, 64)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 61, 128)           24704
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 61, 128)           512
# _________________________________________________________________
# dense_2 (Dense)              (None, 61, 128)           16512
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 59, 256)           98560
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 59, 256)           1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 59, 256)           65792
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 57, 512)           393728
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 57, 512)           2048
# _________________________________________________________________
# dense_4 (Dense)              (None, 57, 512)           262656
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 55, 1024)          1573888
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 55, 1024)          4096
# _________________________________________________________________
# dense_5 (Dense)              (None, 55, 1024)          1049600
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 53, 2048)          6293504
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 53, 2048)          8192
# _________________________________________________________________
# dense_6 (Dense)              (None, 53, 2048)          4196352
# _________________________________________________________________
# flatten (Flatten)            (None, 108544)            0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2048)              222300160
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 2048)              8192
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 2048)              8192
# _________________________________________________________________
# dense_8 (Dense)              (None, 9)                 18441
# =================================================================
# Total params: 236,338,569
# Trainable params: 236,322,249
# Non-trainable params: 16,320
# _________________________________________________________________

# %%
#만약 overfitting, underfitting 을 일으키면 EarlyStopping을 쓰기 위한 코드
#patience가 5면 validation score가 5회 이상 개선이 없을때 훈련을 멈춘다

from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_accuracy', patience=5, min_delta=0.005)

# %%
#model traing
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy']) #rmsprop or adam , accuracy or f1-score  (positive와 negative의 데이터 값 차이가 높을 경우)
history = model.fit(X_train,Y_train, epochs=100, batch_size=20) #callbacks=[es])
# Out:
# Epoch 1/100
# 375/375 [==============================] - 72s 62ms/step - loss: 1.1362 - accuracy: 0.7004
# Epoch 2/100
# 375/375 [==============================] - 23s 62ms/step - loss: 0.3159 - accuracy: 0.8850
# Epoch 3/100
# 375/375 [==============================] - 23s 62ms/step - loss: 0.2111 - accuracy: 0.9143
# Epoch 4/100
# 375/375 [==============================] - 24s 63ms/step - loss: 0.1984 - accuracy: 0.9160
# Epoch 5/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1909 - accuracy: 0.9191
# Epoch 6/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1666 - accuracy: 0.9313
# Epoch 7/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1516 - accuracy: 0.9355
# Epoch 8/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1569 - accuracy: 0.9329
# Epoch 9/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1587 - accuracy: 0.9303
# Epoch 10/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1456 - accuracy: 0.9374
# Epoch 11/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1458 - accuracy: 0.9334
# Epoch 12/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1341 - accuracy: 0.9452
# Epoch 13/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1269 - accuracy: 0.9415
# Epoch 14/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1371 - accuracy: 0.9387
# Epoch 15/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1216 - accuracy: 0.9505
# Epoch 16/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1261 - accuracy: 0.9446
# Epoch 17/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.1286 - accuracy: 0.9469
# Epoch 18/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1096 - accuracy: 0.9545
# Epoch 19/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1027 - accuracy: 0.9540
# Epoch 20/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1106 - accuracy: 0.9532
# Epoch 21/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1156 - accuracy: 0.9511
# Epoch 22/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1004 - accuracy: 0.9604
# Epoch 23/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0957 - accuracy: 0.9611
# Epoch 24/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0815 - accuracy: 0.9640
# Epoch 25/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0879 - accuracy: 0.9628
# Epoch 26/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0870 - accuracy: 0.9637
# Epoch 27/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1018 - accuracy: 0.9603
# Epoch 28/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0892 - accuracy: 0.9604
# Epoch 29/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0878 - accuracy: 0.9617
# Epoch 30/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0820 - accuracy: 0.9693
# Epoch 31/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1201 - accuracy: 0.9506
# Epoch 32/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0961 - accuracy: 0.9601
# Epoch 33/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0984 - accuracy: 0.9588
# Epoch 34/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0913 - accuracy: 0.9631
# Epoch 35/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0827 - accuracy: 0.9701
# Epoch 36/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0794 - accuracy: 0.9661
# Epoch 37/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0695 - accuracy: 0.9731
# Epoch 38/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0752 - accuracy: 0.9692
# Epoch 39/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0747 - accuracy: 0.9671
# Epoch 40/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0719 - accuracy: 0.9691
# Epoch 41/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0832 - accuracy: 0.9658
# Epoch 42/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0699 - accuracy: 0.9699
# Epoch 43/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0905 - accuracy: 0.9689
# Epoch 44/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0659 - accuracy: 0.9745
# Epoch 45/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0696 - accuracy: 0.9727
# Epoch 46/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0800 - accuracy: 0.9702
# Epoch 47/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0574 - accuracy: 0.9780
# Epoch 48/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0650 - accuracy: 0.9762
# Epoch 49/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0629 - accuracy: 0.9749
# Epoch 50/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0756 - accuracy: 0.9714
# Epoch 51/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0598 - accuracy: 0.9757
# Epoch 52/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0507 - accuracy: 0.9773
# Epoch 53/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0642 - accuracy: 0.9721
# Epoch 54/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0569 - accuracy: 0.9785
# Epoch 55/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0596 - accuracy: 0.9767
# Epoch 56/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0600 - accuracy: 0.9755
# Epoch 57/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0519 - accuracy: 0.9785
# Epoch 58/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0548 - accuracy: 0.9784
# Epoch 59/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0471 - accuracy: 0.9818
# Epoch 60/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0493 - accuracy: 0.9814
# Epoch 61/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0403 - accuracy: 0.9841
# Epoch 62/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0582 - accuracy: 0.9789
# Epoch 63/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0432 - accuracy: 0.9837
# Epoch 64/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0474 - accuracy: 0.9807
# Epoch 65/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0489 - accuracy: 0.9824
# Epoch 66/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0556 - accuracy: 0.9797
# Epoch 67/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0481 - accuracy: 0.9833
# Epoch 68/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0538 - accuracy: 0.9782
# Epoch 69/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0682 - accuracy: 0.9762
# Epoch 70/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.1121 - accuracy: 0.9562
# Epoch 71/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0976 - accuracy: 0.9631
# Epoch 72/100
# 375/375 [==============================] - 24s 65ms/step - loss: 0.0877 - accuracy: 0.9655
# Epoch 73/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0667 - accuracy: 0.9734
# Epoch 74/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0750 - accuracy: 0.9699
# Epoch 75/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0760 - accuracy: 0.9721
# Epoch 76/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0563 - accuracy: 0.9788
# Epoch 77/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0821 - accuracy: 0.9658
# Epoch 78/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0568 - accuracy: 0.9795
# Epoch 79/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0482 - accuracy: 0.9802
# Epoch 80/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0496 - accuracy: 0.9821
# Epoch 81/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0427 - accuracy: 0.9856
# Epoch 82/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0354 - accuracy: 0.9869
# Epoch 83/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0387 - accuracy: 0.9855
# Epoch 84/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0384 - accuracy: 0.9848
# Epoch 85/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0469 - accuracy: 0.9816
# Epoch 86/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0359 - accuracy: 0.9881
# Epoch 87/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0413 - accuracy: 0.9846
# Epoch 88/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0376 - accuracy: 0.9864
# Epoch 89/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0379 - accuracy: 0.9871
# Epoch 90/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0394 - accuracy: 0.9857
# Epoch 91/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0379 - accuracy: 0.9849
# Epoch 92/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0365 - accuracy: 0.9854
# Epoch 93/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0347 - accuracy: 0.9883
# Epoch 94/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0322 - accuracy: 0.9881
# Epoch 95/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0311 - accuracy: 0.9889
# Epoch 96/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0339 - accuracy: 0.9883
# Epoch 97/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0273 - accuracy: 0.9897
# Epoch 98/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0246 - accuracy: 0.9905
# Epoch 99/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0244 - accuracy: 0.9924
# Epoch 100/100
# 375/375 [==============================] - 24s 64ms/step - loss: 0.0283 - accuracy: 0.9889

# %%
#훈련 및 검증 정확도 시각화
#학습 정확성 값과 검증 정확성 값
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# 학습 손실 값과 검증 손실 값
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# %%
preds = model.predict(X_test)
preds = np.argmax(preds, axis=1)
preds
# Out:
# array([4, 1, 4, ..., 2, 0, 2])

# %%
#model save
submission = pd.read_csv('/content/drive/MyDrive/딥러닝 AI+X/submission.csv')
submission['Predicted Label'] = preds
submission.to_csv('submission_file.csv', index=False)
submission
# Out:
#       Trial  Predicted Label
# 0         0                4
# 1         1                1
# 2         2                4
# 3         3                0
# 4         4                0
# ...     ...              ...
# 3212   3212                5
# 3213   3213                1
# 3214   3214                2
# 3215   3215                0
# 3216   3216                2
#
# [3217 rows x 2 columns]
