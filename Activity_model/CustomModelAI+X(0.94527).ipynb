# %%
#Drive Mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#GPU 
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#Data load
import numpy as np
import pandas as pd

X_train = np.load('/content/drive/MyDrive/딥러닝 AI+X/train_x.npy')
Y_train = np.load('/content/drive/MyDrive/딥러닝 AI+X/train_y.npy')
X_test = np.load('/content/drive/MyDrive/딥러닝 AI+X/test_x.npy')
Y_test  = pd.read_csv("/content/drive/MyDrive/딥러닝 AI+X/submission.csv").values
print(np.shape(X_train))
print(np.shape(Y_train))
print(np.shape(X_test))
print(np.shape(Y_test))
# Out:
# (7494, 128, 6)
# (7494, 9)
# (3217, 128, 6)
# (3217, 2)

# %%
#Model Library
from keras.models import Sequential, Model
from keras.layers import Conv1D, MaxPooling1D,BatchNormalization
from keras.callbacks import EarlyStopping, LambdaCallback
from keras.layers import Activation, Dropout,Input, Flatten, Dense

# %%
#Convolutional Layer
model = Sequential()
model.add(Conv1D(32, kernel_size=3, input_shape=(128, 6)))
model.add(BatchNormalization(axis=-1))
model.add(Dense(32, activation='relu'))

model.add(Conv1D(64, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(64, activation='relu'))

model.add(Conv1D(128, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(128, activation='relu'))

model.add(Conv1D(256, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(256, activation='relu'))

model.add(Conv1D(512, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(512, activation='relu'))

model.add(Conv1D(1024, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(1024, activation='relu'))

# %%
#Output Layer
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.5))
model.add(BatchNormalization(axis=-1))
model.add(Dense(9, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 126, 32)           608
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 126, 32)           128
# _________________________________________________________________
# dense_8 (Dense)              (None, 126, 32)           1056
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 124, 64)           6208
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 124, 64)           256
# _________________________________________________________________
# dense_9 (Dense)              (None, 124, 64)           4160
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 122, 128)          24704
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 122, 128)          512
# _________________________________________________________________
# dense_10 (Dense)             (None, 122, 128)          16512
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 120, 256)          98560
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 120, 256)          1024
# _________________________________________________________________
# dense_11 (Dense)             (None, 120, 256)          65792
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 118, 512)          393728
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 118, 512)          2048
# _________________________________________________________________
# dense_12 (Dense)             (None, 118, 512)          262656
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 116, 1024)         1573888
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 116, 1024)         4096
# _________________________________________________________________
# dense_13 (Dense)             (None, 116, 1024)         1049600
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 118784)            0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1024)              121635840
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 1024)              4096
# _________________________________________________________________
# dense_15 (Dense)             (None, 9)                 9225
# =================================================================
# Total params: 125,158,793
# Trainable params: 125,150,665
# Non-trainable params: 8,128
# _________________________________________________________________

# %%
#만약 overfitting, underfitting 을 일으키면 EarlyStopping을 쓰기 위한 코드
#patience가 5면 validation score가 5회 이상 개선이 없을때 훈련을 멈춘다

from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_accuracy', patience=5, min_delta=0.005)

# %%
#model traing
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy']) #rmsprop or adam , accuracy or f1-score  (positive와 negative의 데이터 값 차이가 높을 경우)
history = model.fit(X_train,Y_train, epochs=100, batch_size=20) #callbacks=[es])
# Out:
# Epoch 1/100
# 250/250 [==============================] - 16s 49ms/step - loss: 0.7640 - accuracy: 0.7466
# Epoch 2/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.2049 - accuracy: 0.9160
# Epoch 3/100
# 250/250 [==============================] - 12s 50ms/step - loss: 0.1884 - accuracy: 0.9243
# Epoch 4/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.1496 - accuracy: 0.9359
# Epoch 5/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.1269 - accuracy: 0.9492
# Epoch 6/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.1012 - accuracy: 0.9620
# Epoch 7/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.1033 - accuracy: 0.9532
# Epoch 8/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.1104 - accuracy: 0.9562
# Epoch 9/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.1046 - accuracy: 0.9588
# Epoch 10/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0931 - accuracy: 0.9607
# Epoch 11/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.1053 - accuracy: 0.9589
# Epoch 12/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0941 - accuracy: 0.9575
# Epoch 13/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0896 - accuracy: 0.9625
# Epoch 14/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0808 - accuracy: 0.9677
# Epoch 15/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0746 - accuracy: 0.9692
# Epoch 16/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0763 - accuracy: 0.9690
# Epoch 17/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0802 - accuracy: 0.9652
# Epoch 18/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0907 - accuracy: 0.9596
# Epoch 19/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0892 - accuracy: 0.9659
# Epoch 20/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0790 - accuracy: 0.9669
# Epoch 21/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0712 - accuracy: 0.9695
# Epoch 22/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0841 - accuracy: 0.9675
# Epoch 23/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0705 - accuracy: 0.9724
# Epoch 24/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0798 - accuracy: 0.9702
# Epoch 25/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0631 - accuracy: 0.9765
# Epoch 26/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0622 - accuracy: 0.9750
# Epoch 27/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0609 - accuracy: 0.9761
# Epoch 28/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0544 - accuracy: 0.9803
# Epoch 29/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0774 - accuracy: 0.9701
# Epoch 30/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0686 - accuracy: 0.9721
# Epoch 31/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0657 - accuracy: 0.9731
# Epoch 32/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0603 - accuracy: 0.9755
# Epoch 33/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0588 - accuracy: 0.9772
# Epoch 34/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0572 - accuracy: 0.9768
# Epoch 35/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0480 - accuracy: 0.9845
# Epoch 36/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0562 - accuracy: 0.9775
# Epoch 37/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0560 - accuracy: 0.9776
# Epoch 38/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0630 - accuracy: 0.9744
# Epoch 39/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0467 - accuracy: 0.9810
# Epoch 40/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0513 - accuracy: 0.9810
# Epoch 41/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0505 - accuracy: 0.9803
# Epoch 42/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0564 - accuracy: 0.9773
# Epoch 43/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0540 - accuracy: 0.9793
# Epoch 44/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0458 - accuracy: 0.9818
# Epoch 45/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0453 - accuracy: 0.9844
# Epoch 46/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0455 - accuracy: 0.9814
# Epoch 47/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0369 - accuracy: 0.9863
# Epoch 48/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0402 - accuracy: 0.9858
# Epoch 49/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0400 - accuracy: 0.9841
# Epoch 50/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0442 - accuracy: 0.9839
# Epoch 51/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0796 - accuracy: 0.9743
# Epoch 52/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.1288 - accuracy: 0.9470
# Epoch 53/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0996 - accuracy: 0.9603
# Epoch 54/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0941 - accuracy: 0.9591
# Epoch 55/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0829 - accuracy: 0.9654
# Epoch 56/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0788 - accuracy: 0.9658
# Epoch 57/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0666 - accuracy: 0.9751
# Epoch 58/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0681 - accuracy: 0.9724
# Epoch 59/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0848 - accuracy: 0.9635
# Epoch 60/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0582 - accuracy: 0.9755
# Epoch 61/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0481 - accuracy: 0.9830
# Epoch 62/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0508 - accuracy: 0.9806
# Epoch 63/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0476 - accuracy: 0.9806
# Epoch 64/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0521 - accuracy: 0.9793
# Epoch 65/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0454 - accuracy: 0.9827
# Epoch 66/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0374 - accuracy: 0.9852
# Epoch 67/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0478 - accuracy: 0.9801
# Epoch 68/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0339 - accuracy: 0.9876
# Epoch 69/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0364 - accuracy: 0.9869
# Epoch 70/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0418 - accuracy: 0.9854
# Epoch 71/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0428 - accuracy: 0.9832
# Epoch 72/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0404 - accuracy: 0.9847
# Epoch 73/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0358 - accuracy: 0.9855
# Epoch 74/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0359 - accuracy: 0.9866
# Epoch 75/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0385 - accuracy: 0.9870
# Epoch 76/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0356 - accuracy: 0.9860
# Epoch 77/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0343 - accuracy: 0.9879
# Epoch 78/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0269 - accuracy: 0.9905
# Epoch 79/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0297 - accuracy: 0.9881
# Epoch 80/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0456 - accuracy: 0.9849
# Epoch 81/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0384 - accuracy: 0.9859
# Epoch 82/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0444 - accuracy: 0.9843
# Epoch 83/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0536 - accuracy: 0.9818
# Epoch 84/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0327 - accuracy: 0.9869
# Epoch 85/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0403 - accuracy: 0.9857
# Epoch 86/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0335 - accuracy: 0.9872
# Epoch 87/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0280 - accuracy: 0.9910
# Epoch 88/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0245 - accuracy: 0.9908
# Epoch 89/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0229 - accuracy: 0.9909
# Epoch 90/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0238 - accuracy: 0.9909
# Epoch 91/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0311 - accuracy: 0.9879
# Epoch 92/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0339 - accuracy: 0.9870
# Epoch 93/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0844 - accuracy: 0.9705
# Epoch 94/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.1205 - accuracy: 0.9515
# Epoch 95/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0769 - accuracy: 0.9701
# Epoch 96/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0681 - accuracy: 0.9717
# Epoch 97/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0601 - accuracy: 0.9771
# Epoch 98/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0495 - accuracy: 0.9813
# Epoch 99/100
# 250/250 [==============================] - 12s 49ms/step - loss: 0.0502 - accuracy: 0.9803
# Epoch 100/100
# 250/250 [==============================] - 12s 48ms/step - loss: 0.0404 - accuracy: 0.9852

# %%
#훈련 및 검증 정확도 시각화
#학습 정확성 값과 검증 정확성 값
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# 학습 손실 값과 검증 손실 값
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# %%
preds = model.predict(X_test)
preds = np.argmax(preds, axis=1)
preds
# Out:
# array([4, 1, 4, ..., 2, 0, 2])

# %%
#model save
submission = pd.read_csv('/content/drive/MyDrive/딥러닝 AI+X/submission.csv')
submission['Predicted Label'] = preds
submission.to_csv('submission_file.csv', index=False)
submission
# Out:
#       Trial  Predicted Label
# 0         0                4
# 1         1                1
# 2         2                4
# 3         3                0
# 4         4                0
# ...     ...              ...
# 3212   3212                5
# 3213   3213                1
# 3214   3214                2
# 3215   3215                0
# 3216   3216                2
#
# [3217 rows x 2 columns]
