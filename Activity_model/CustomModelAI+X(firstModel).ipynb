# %%
#Drive Mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#GPU 
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#Data load
import numpy as np
import pandas as pd

X_train = np.load('/content/drive/MyDrive/딥러닝 AI+X/train_x.npy')
Y_train = np.load('/content/drive/MyDrive/딥러닝 AI+X/train_y.npy')
X_test = np.load('/content/drive/MyDrive/딥러닝 AI+X/test_x.npy')
Y_test  = pd.read_csv("/content/drive/MyDrive/딥러닝 AI+X/submission.csv").values
print(np.shape(X_train))
print(np.shape(Y_train))
print(np.shape(X_test))
print(np.shape(Y_test))
# Out:
# (7494, 128, 6)
# (7494, 9)
# (3217, 128, 6)
# (3217, 2)

# %%
#Model Library
from keras.models import Sequential, Model
from keras.layers import Conv1D, MaxPooling1D,BatchNormalization
from keras.callbacks import EarlyStopping, LambdaCallback
from keras.layers import Activation, Dropout,Input, Flatten, Dense

# %%
#Convolutional Layer
model = Sequential()
model.add(Conv1D(32, kernel_size=3, input_shape=(128, 6),padding = 'same'))
model.add(BatchNormalization(axis=-1))
model.add(Dense(32, activation='relu'))


model.add(Conv1D(64, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(64, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

model.add(Conv1D(128, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(128, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

model.add(Conv1D(256, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(256, activation='relu'))


model.add(Conv1D(512, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(512, activation='relu'))


model.add(Conv1D(1024, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(1024, activation='relu'))

model.add(Conv1D(2048, kernel_size=3))
model.add(BatchNormalization(axis=-1))
model.add(Dense(2048, activation='relu'))

# %%
#Output Layer
model.add(Flatten())
model.add(Dense(2048, activation='relu'))
model.add(BatchNormalization(axis=-1))
model.add(Dropout(0.8))
model.add(BatchNormalization(axis=-1))
model.add(Dense(9, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_7 (Conv1D)            (None, 128, 32)           608
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128, 32)           128
# _________________________________________________________________
# dense_9 (Dense)              (None, 128, 32)           1056
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 126, 64)           6208
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 126, 64)           256
# _________________________________________________________________
# dense_10 (Dense)             (None, 126, 64)           4160
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 63, 64)            0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 61, 128)           24704
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 61, 128)           512
# _________________________________________________________________
# dense_11 (Dense)             (None, 61, 128)           16512
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 30, 128)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 28, 256)           98560
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 28, 256)           1024
# _________________________________________________________________
# dense_12 (Dense)             (None, 28, 256)           65792
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 26, 512)           393728
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 26, 512)           2048
# _________________________________________________________________
# dense_13 (Dense)             (None, 26, 512)           262656
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 24, 1024)          1573888
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 24, 1024)          4096
# _________________________________________________________________
# dense_14 (Dense)             (None, 24, 1024)          1049600
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 22, 2048)          6293504
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 22, 2048)          8192
# _________________________________________________________________
# dense_15 (Dense)             (None, 22, 2048)          4196352
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 45056)             0
# _________________________________________________________________
# dense_16 (Dense)             (None, 2048)              92276736
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 2048)              8192
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 2048)              8192
# _________________________________________________________________
# dense_17 (Dense)             (None, 9)                 18441
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 9)                 0
# _________________________________________________________________
# dense_18 (Dense)             (None, 2048)              20480
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 2048)              8192
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 2048)              8192
# _________________________________________________________________
# dense_19 (Dense)             (None, 9)                 18441
# =================================================================
# Total params: 106,370,450
# Trainable params: 106,345,938
# Non-trainable params: 24,512
# _________________________________________________________________

# %%
#만약 overfitting, underfitting 을 일으키면 EarlyStopping을 쓰기 위한 코드
#patience가 5면 validation score가 5회 이상 개선이 없을때 훈련을 멈춘다

from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_accuracy', patience=5, min_delta=0.005)

# %%
#model traing
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy']) #rmsprop or adam , accuracy or f1-score  (positive와 negative의 데이터 값 차이가 높을 경우)
history = model.fit(X_train,Y_train, epochs=100, batch_size=20) #callbacks=[es])
# Out:
# Epoch 1/100
# 375/375 [==============================] - 17s 35ms/step - loss: 1.4948 - accuracy: 0.4921
# Epoch 2/100
# 375/375 [==============================] - 13s 35ms/step - loss: 0.9598 - accuracy: 0.6894
# Epoch 3/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.7965 - accuracy: 0.7563
# Epoch 4/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.6695 - accuracy: 0.8131
# Epoch 5/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.5670 - accuracy: 0.8410
# Epoch 6/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.4714 - accuracy: 0.8652
# Epoch 7/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.4382 - accuracy: 0.8725
# Epoch 8/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.4020 - accuracy: 0.8819
# Epoch 9/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3428 - accuracy: 0.8953
# Epoch 10/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3337 - accuracy: 0.8886
# Epoch 11/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3505 - accuracy: 0.8959
# Epoch 12/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3562 - accuracy: 0.8913
# Epoch 13/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2951 - accuracy: 0.8950
# Epoch 14/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2716 - accuracy: 0.9188
# Epoch 15/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3124 - accuracy: 0.9051
# Epoch 16/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3148 - accuracy: 0.9070
# Epoch 17/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2887 - accuracy: 0.9045
# Epoch 18/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2659 - accuracy: 0.9122
# Epoch 19/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2840 - accuracy: 0.8997
# Epoch 20/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2556 - accuracy: 0.9176
# Epoch 21/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3067 - accuracy: 0.8990
# Epoch 22/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2992 - accuracy: 0.9077
# Epoch 23/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2958 - accuracy: 0.9047
# Epoch 24/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2727 - accuracy: 0.9061
# Epoch 25/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2710 - accuracy: 0.9145
# Epoch 26/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2481 - accuracy: 0.9123
# Epoch 27/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3522 - accuracy: 0.8773
# Epoch 28/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.7999 - accuracy: 0.6876
# Epoch 29/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.5462 - accuracy: 0.7800
# Epoch 30/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.4754 - accuracy: 0.7946
# Epoch 31/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.4259 - accuracy: 0.7900
# Epoch 32/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3903 - accuracy: 0.8602
# Epoch 33/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3201 - accuracy: 0.8978
# Epoch 34/100
# 375/375 [==============================] - 13s 35ms/step - loss: 0.3578 - accuracy: 0.8864
# Epoch 35/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3117 - accuracy: 0.9045
# Epoch 36/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2756 - accuracy: 0.9165
# Epoch 37/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2758 - accuracy: 0.9118
# Epoch 38/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2652 - accuracy: 0.9124
# Epoch 39/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2785 - accuracy: 0.9190
# Epoch 40/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2909 - accuracy: 0.9080
# Epoch 41/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2410 - accuracy: 0.9247
# Epoch 42/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2365 - accuracy: 0.9219
# Epoch 43/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2817 - accuracy: 0.9157
# Epoch 44/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2845 - accuracy: 0.9116
# Epoch 45/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2511 - accuracy: 0.9139
# Epoch 46/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2357 - accuracy: 0.9249
# Epoch 47/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2580 - accuracy: 0.9202
# Epoch 48/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2566 - accuracy: 0.9160
# Epoch 49/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2670 - accuracy: 0.9102
# Epoch 50/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.3188 - accuracy: 0.8973
# Epoch 51/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2464 - accuracy: 0.9237
# Epoch 52/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2164 - accuracy: 0.9223
# Epoch 53/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2677 - accuracy: 0.9071
# Epoch 54/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2457 - accuracy: 0.9255
# Epoch 55/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2618 - accuracy: 0.9200
# Epoch 56/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2228 - accuracy: 0.9231
# Epoch 57/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2275 - accuracy: 0.9279
# Epoch 58/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2532 - accuracy: 0.9083
# Epoch 59/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2252 - accuracy: 0.9260
# Epoch 60/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2593 - accuracy: 0.9090
# Epoch 61/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2260 - accuracy: 0.9245
# Epoch 62/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2209 - accuracy: 0.9282
# Epoch 63/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2328 - accuracy: 0.9238
# Epoch 64/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2137 - accuracy: 0.9279
# Epoch 65/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2300 - accuracy: 0.9214
# Epoch 66/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2234 - accuracy: 0.9184
# Epoch 67/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2527 - accuracy: 0.9167
# Epoch 68/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2123 - accuracy: 0.9241
# Epoch 69/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2550 - accuracy: 0.9181
# Epoch 70/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2035 - accuracy: 0.9301
# Epoch 71/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2008 - accuracy: 0.9309
# Epoch 72/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2422 - accuracy: 0.9182
# Epoch 73/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2377 - accuracy: 0.9182
# Epoch 74/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2317 - accuracy: 0.9219
# Epoch 75/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2110 - accuracy: 0.9279
# Epoch 76/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2123 - accuracy: 0.9316
# Epoch 77/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2112 - accuracy: 0.9216
# Epoch 78/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2381 - accuracy: 0.9194
# Epoch 79/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2155 - accuracy: 0.9207
# Epoch 80/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2142 - accuracy: 0.9242
# Epoch 81/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2231 - accuracy: 0.9277
# Epoch 82/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2198 - accuracy: 0.9215
# Epoch 83/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2307 - accuracy: 0.9244
# Epoch 84/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2317 - accuracy: 0.9262
# Epoch 85/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2112 - accuracy: 0.9290
# Epoch 86/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2068 - accuracy: 0.9295
# Epoch 87/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2108 - accuracy: 0.9263
# Epoch 88/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2029 - accuracy: 0.9235
# Epoch 89/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.1994 - accuracy: 0.9317
# Epoch 90/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.1871 - accuracy: 0.9336
# Epoch 91/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.1937 - accuracy: 0.9312
# Epoch 92/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2028 - accuracy: 0.9282
# Epoch 93/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2425 - accuracy: 0.9247
# Epoch 94/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2092 - accuracy: 0.9241
# Epoch 95/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.1799 - accuracy: 0.9381
# Epoch 96/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2140 - accuracy: 0.9303
# Epoch 97/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.1920 - accuracy: 0.9316
# Epoch 98/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2455 - accuracy: 0.9196
# Epoch 99/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.1893 - accuracy: 0.9387
# Epoch 100/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.2107 - accuracy: 0.9362

# %%
#훈련 및 검증 정확도 시각화
#학습 정확성 값과 검증 정확성 값
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# 학습 손실 값과 검증 손실 값
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# %%
preds = model.predict(X_test)
preds = np.argmax(preds, axis=1)
preds
# Out:
# array([4, 1, 4, ..., 2, 0, 2])

# %%
#model save
submission = pd.read_csv('/content/drive/MyDrive/딥러닝 AI+X/submission.csv')
submission['Predicted Label'] = preds
submission.to_csv('submission_file.csv', index=False)
submission
# Out:
#       Trial  Predicted Label
# 0         0                4
# 1         1                1
# 2         2                4
# 3         3                0
# 4         4                0
# ...     ...              ...
# 3212   3212                5
# 3213   3213                1
# 3214   3214                2
# 3215   3215                0
# 3216   3216                2
#
# [3217 rows x 2 columns]
